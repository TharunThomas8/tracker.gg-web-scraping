# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import time
from datetime import datetime
from selenium.common.exceptions import NoSuchElementException
from datetime import date
from selenium.webdriver.common.by import By
import pandas as pd
# Out:
# c:\Users\tharu\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
url = 'https://tracker.gg/valorant/lfg'
test = 'https://www.google.com/'
browser = webdriver.Chrome(executable_path='D:/Study/TCD/ML/grp/chromedriver')
table_xpath = '/html/body/div/div[2]/div[2]/div/main/div[3]/div[3]/div[2]/div/div[2]/table'

browser.get(url)
time.sleep(5)


matchs = browser.find_elements(By.TAG_NAME, 'tr')

rank = []
mode = []
win_per = []
kd = []
dmg_per_rnd = []



for m in matchs:

    # username.append(m.find_elements(By.XPATH, './/td[1]')[0].text)
    for u in m.find_elements(By.XPATH, './/td[2]'):
        # print(u.text+"-----")
        rank.append(u.text)
    
    for u in m.find_elements(By.XPATH, './/td[3]'):
        # print(u.text+"-----")
        mode.append(u.text)
    
    for u in m.find_elements(By.XPATH, './/td[4]'):
        # print(u.text+"-----")
        win_per.append(u.text)
    
    for u in m.find_elements(By.XPATH, './/td[5]'):
        # print(u.text+"-----")
        kd.append(u.text)
    
    for u in m.find_elements(By.XPATH, './/td[6]'):
        # print(u.text+"-----")
        dmg_per_rnd.append(u.text)


player_tag_xpath = "/html/body/div/div[2]/div[2]/div/main/div[3]/div[3]/div[2]/div/div[2]/table/tbody/tr/td[1]/div/span"
player_tag = browser.find_elements(By.XPATH, player_tag_xpath)
# matchs = browser.find_elements(By.XPATH, './/td[1]')
# f = 0
# i = 1
id = []

for i in player_tag:
    # ids.append(i.text)
    id.append((str(i.text).replace("\n", "")))
    # print(str(i.text))

region = []
cnt_of_child = 0
pr = '/html/body/div/div[2]/div[2]/div/main/div[3]/div[3]/div[2]/div/div[2]/table/tbody/tr/td[1]/div/div'
parnt = browser.find_elements(By.XPATH,pr)
# print(matchs)
for m in parnt:
    # for u in m.find_elements(By.XPATH, './/img[1]'):
    #     print((m.get_attribute("src")))
    cnt_of_child = 0
    for u in m.find_elements(By.XPATH, './/child::img'):
        # print((m.get_attribute("class")))
        # print("true")
        cnt_of_child = 1+cnt_of_child
    
    if(cnt_of_child==2):
        a_c = m.find_elements(By.XPATH,("./*"))
        f = 0
        for c in a_c:
            if(f==1):
                region.append(c.get_attribute("title"))
            f = f + 1
    else:
        region.append("None")
            # print("here")
    # print("-------")

browser.quit()

print(id)
print(len(id))
print(len(rank))
print(len(mode))
print(len(win_per))
print(len(kd))
print(len(dmg_per_rnd))
print(len(region))
# Out:
# ['Trica Bejoan#DUTCH', 'AaronHasMoney#Gang', 'Rayness#bees', 'c0L#1081', 'A L E X#ANIME', 'Ayana#Egirl', 'i miss him#ughhh', 'Sparkly#6969', 'Akimbo#00001', 'V1 Vlu#777', 'toaster#7652', 'Soar#1428', 'DffFxy#8694', 'quoiS#LOVEU', 'Hybrid#9181', 'GS Kwimpyy#strn', 'TheSearch#1429', 'GiraffeJiggler80#9996', 'GoHardMurky#Dor', 'Just Coco#NAW', 'Seliyas#4183', 'crallkk#EUW', 'MaestroKing#2526', 'PhenomXO#EZZ', 'Ram#re0', 'YumekoJabami#UwU', 'shini#boo', 'Fusional#9764', 'SINDBAD#000', 'kytchu#kawai', 'lester#asss', 'R1chard3k#GRAND', 'Khaled#exe', 'FallenAngel#6025', 'Weason#wgod', 'máquina#so ez', 'VLTNVally#1527', 'ilovemcflurry123#flurr', 'Sife#1991', 'RazrivatelAHYCOB#8888', 'ShotGunPlayer#1995', 'MB A1mz#King', 'karuszczak#EUNE', 'beetlejuice#369', 'bro1g1#6996', 'MP KaiserXImpact#God', 'lookin for mommy#eboy', 'auto dnd#auto', 'FyaH#ESP', 'Ryuga#8055', 'Gotakson#0001', 'eng Na Choice đá#MinHy', 'kody#0444', 'arri#7777', 'Spice#Mommy', 'Palmolives#6640', 'kimanier#EUW', 'hackerend#booby', 'KC7#BP88', 'wise#1000', 'Luminite#Come', 'Sir McGirth#big', 'MyLove#you', 'mantoneee#xhek', 'Skull Shocker#Solo', 'Scaleny#Dakk', 'Sora#SO02', 'B0Y#00002', 'Lepatats#EUW', 'kuvi#rina', 'brat#CSGO', 'Medou#FUNDR', 'Kajitsulol#Rusty', 'B3ASTM0D3#LANA', 'flyingmyvi#MYVI', 'romelpezzzz#nashe', 'XarDrax#drax', 'Masala Chicken#1212', 'clarify#2369', 'Aurxllie#bunny', 'Dysania#AWAKE', 'MrCrked#7322', 'PITFALLTV#N01', 'Rambo#8704', 'ArtudNay#Kat', 'daylight pill#4081', 'vitalis961#2031', 'Nvoyn3r#6456', 'ладно#9529', 'SkillfulBubbleT#5294', 'Valentine#vel', 'GBoyHi#NOOB', 'agooo#007', 'Individuo30#6524', 'дед быдла#daddy', 'SwagAngel#whiff', 'Smeedrejat#best', 'Radikaler Ronny#afd', 'RyaanxX#9910', 'september 24#1805', 'Obstsalat#Miau', 'Blackyy#Trxsh', 'kukasbacsi#tej', 'Fladalu#EUW', 'SKIL#3115', 'BAKI HANMA#6128', 'clav111#111', 'DucksGoQuack#nolol', 'ZachMadeekBeach#6969', 'eastdakota208#9002', 'Iceッ#0406', 'N0t4lxx#2140', 'd0nt#1taps', 'Bloomhed#9623', 'Kashya#Sage', 'GeTreXx#Bucky', 'cobra#0666', 'Elαッ#Krmit', 'British Man#Brit', 'FriendlyNSG#4488', 'PH0EN1X#CoW', 'Asher#ohayo', 'need feet pics#666', 'emevaelx#1337', 'Za Russian секс7#maks7', '이 년들을 믿지마#0307', 'SHADOW#OOOO', 'Rodys Tricks#777', 'JETAway#way', 'IRZ dragnwsniper#irzfy', 'bunnyheadbaby#9251', 'Ricmaranga#GGs', 'ChaosXIII#XIII', 'TRIS TAINT#imbad', 'cinnabunny#boo', 'dynamickitty23#0001', 'andjelaツ#2424', 'riceuwu#666', 'FTSW Tubbirdd#Zaddy', 'Rule34#3207', 'kia kaha#7405', 'TGS itzy#TTV', 'RikaChuz#EUW', 'RikaChu#7224', 'zertuny#1220', 'her moon#lxrd', 'AMBASSADOR#NOTAG', 'goofy ahh xotic#0000', 'LAUHAX#1337', 'Tokyoo#Jihyo', 'iVyLux#002', 'interlude#aceml', 'G2K Ch1kita#Suz', 'seireИ 吉神#ynwa', 'BigTiddieGoth#alone', 'f0urK#death', '黒Jet#dead', 'Maey#nani', 'G2K Tessa#1668', 'xShootzxx#GOAT', 'Epablo#1212', 'NowHiringKittens#BIG D', 'Xess#Clean', 'Oli#4500', 'Chear#3383', 'Fantazer#8131', 'Axela0ss#01113', 'Kyedoo#shoko', 'Byakya#AIM', 'GMB DoJ#69420', 'よわよわのゆう#WCT', 'TL F4rceFlash#TTV', 'atomcorp#COZA', 'Alxc#Vibes', 'Tripppy#OCE', 'kelow#domi', 'Fornika2r#dontu', 'zadiakdeuS#nashe', 'Master Oogway#1155', 'peachy#0806', 'valazio195#BUMI', 'MezX#06060', 'degoreo#nyaw', 'YAHANU#1308', 'monkedesgraciao#monke', 'ItsLiu#0001', 'OnYourLeft#十十十', 'STRANGe#Tenz', 'rasbarruy#1tap', 'wennsdae#phjei', 'RainyDevil#TTC', 'PachecoTvOficial#2578', 'Yakult#hello', 'drexton#1301', 'feraxhp#Yuly', 'pollo#1205', 'Soupy#1228', 'vye#1only', 'rei#silly', 'forsik#bad', 'ValorJett#6108', 'ttvrevolversmoke#4592', 'Kung Fu Kenny#6449', 'bell#ash', 'Eulogy#IRIS', 'snorlaxxatives#1309', 'dread#1437', 'Exo#IMMO', 'Joyst1ck#1337', 'ADIRE Tressort#BELG', 'Frozen#vlrnt', 'ladies sommelie#carry', 'Skrub#4925', '锅包肉#W01', 'Raékwon#1400', 'NightmareFuel#koka', 'Hodg#1415', 'Shold#4298', 'SLZ TOXiN#69XXX', 'ReverseWK#7299', 'quet#1312', 'Señοrita#Toxic', 'PizzA stEvE#sexy', 'yuk1koちゃん#ITZY', 'FLseleur#4444']
# 225
# 225
# 225
# 225
# 225
# 225
# 225

# %%
acc_head_per = []
acc_head_hits = []
acc_body_per = []
acc_body_hits = []
acc_leg_per = []
acc_leg_hits = []

matchs = []
headshot_per = []
wins = []
kills = []
kill_per_rnd = []

top_agent_name = []
top_agent_time = []
top_agent_matchs = []
top_agent_win_per = []
top_agent_kd = []
top_agent_adr = []

num = 0
for i in id:
    num= num+1
    id_values = i.split("#")
    # print(id_values[0],id_values[1])
    url = 'https://tracker.gg/valorant/profile/riot/'+id_values[0]+'%23'+id_values[1]+'/overview?playlist=competitive&season=all'

    browser = webdriver.Chrome(executable_path='D:/Study/TCD/ML/grp/chromedriver')

    browser.get(url)
    # browser.maximize_window()
    time.sleep(3)
    browser.minimize_window()
    

    try:
        parnt = browser.find_element(By.XPATH,"//*[@class= 'accuracy__stats']/tbody/tr[1]")
        sep = (parnt.text).split(" ")
        # print(sep[1],sep[2]+"--------")
        acc_head_per.append((sep[1]).replace('%',''))
        acc_head_hits.append((sep[2]))

        parnt = browser.find_element(By.XPATH,"//*[@class= 'accuracy__stats']/tbody/tr[2]")
        sep = (parnt.text).split(" ")
        # print(sep[1],sep[2]+"--------")
        acc_body_per.append((sep[1]).replace('%',''))
        acc_body_hits.append((sep[2]))

        parnt = browser.find_element(By.XPATH,"//*[@class= 'accuracy__stats']/tbody/tr[3]")
        sep = (parnt.text).split(" ")
        # print(sep[1],sep[2]+"--------")
        acc_leg_per.append((sep[1]).replace('%',''))
        acc_leg_hits.append((sep[2]))

        parnt = browser.find_element(By.XPATH,"//*[@class= 'segment-stats area-main-stats card bordered header-bordered responsive']/div/div[1]/div[1]/span[2]")
        sep = (parnt.text).split(" ")
        # print(sep[0]+"--------")
        matchs.append((sep[0]))


        parnt = browser.find_element(By.XPATH,"//*[@class= 'giant-stats']/div[3]/div/div/span[2]")
        sep = (parnt.text).split("%")
        # print(sep[0]+"--------")
        headshot_per.append(sep[0])

        parnt = browser.find_elements(By.XPATH,"//*[@class= 'main']/div/div/div/span[2]")
        wins.append(parnt[0].text)
        kills.append(parnt[1].text)
        kill_per_rnd.append(parnt[6].text)
        
        parnt = browser.find_elements(By.XPATH,"//*[@class= 'top-agents area-top-agents']/div/div/div/div[2]/div/div[1]/div")
        # print(parnt[0].text)
        top_agent_name.append(parnt[0].text)
        
        sep = (parnt[1].text).split(" ")
        top_agent_time.append(sep[0])
        # print(sep[0])
        top_agent_matchs.append(parnt[2].text)
        # print(parnt[2].text)
        sep = (parnt[3].text).split("%")
        # print(sep[0])
        top_agent_win_per.append(sep[0])
        # print(parnt[4].text)
        top_agent_kd.append(parnt[4].text)
        # print(parnt[5].text)
        top_agent_adr.append(parnt[5].text)

        # print("-----------")
        print(" Done " + i)
        print(num)

    except NoSuchElementException:
        acc_head_per.append('0')
        acc_head_hits.append('0')
        acc_body_per.append('0')
        acc_body_hits.append('0')
        acc_leg_per.append('0')
        acc_leg_hits.append('0')
        matchs.append("0")
        headshot_per.append('0')
        wins.append('0')
        kills.append('0')
        kill_per_rnd.append('0')
        top_agent_name.append('0')
        top_agent_time.append('0')
        top_agent_matchs.append('0')
        top_agent_win_per.append('0')
        top_agent_kd.append('0')
        top_agent_adr.append('0')

        print("Failed "+i)
        

    browser.quit()
    
    

# print((acc_head_per),(acc_head_hits),acc_body_per,acc_body_hits,acc_leg_per,acc_leg_hits)
# Out:
#  Done Trica Bejoan#DUTCH
# 1
#  Done AaronHasMoney#Gang
# 2
#  Done Rayness#bees
# 3
#  Done c0L#1081
# 4
#  Done A L E X#ANIME
# 5
#  Done Ayana#Egirl
# 6
#  Done i miss him#ughhh
# 7
#  Done Sparkly#6969
# 8
#  Done Akimbo#00001
# 9
#  Done V1 Vlu#777
# 10
#  Done toaster#7652
# 11
#  Done Soar#1428
# 12
#  Done DffFxy#8694
# 13
#  Done quoiS#LOVEU
# 14
#  Done Hybrid#9181
# 15
#  Done GS Kwimpyy#strn
# 16
# Failed TheSearch#1429
# Failed GiraffeJiggler80#9996
#  Done GoHardMurky#Dor
# 19
#  Done Just Coco#NAW
# 20
#  Done Seliyas#4183
# 21
#  Done crallkk#EUW
# 22
#  Done MaestroKing#2526
# 23
#  Done PhenomXO#EZZ
# 24
#  Done Ram#re0
# 25
#  Done YumekoJabami#UwU
# 26
#  Done shini#boo
# 27
#  Done Fusional#9764
# 28
#  Done SINDBAD#000
# 29
#  Done kytchu#kawai
# 30
#  Done lester#asss
# 31
#  Done R1chard3k#GRAND
# 32
#  Done Khaled#exe
# 33
# Failed FallenAngel#6025
#  Done Weason#wgod
# 35
#  Done máquina#so ez
# 36
#  Done VLTNVally#1527
# 37
#  Done ilovemcflurry123#flurr
# 38
#  Done Sife#1991
# 39
#  Done RazrivatelAHYCOB#8888
# 40
#  Done ShotGunPlayer#1995
# 41
#  Done MB A1mz#King
# 42
#  Done karuszczak#EUNE
# 43
#  Done beetlejuice#369
# 44
#  Done bro1g1#6996
# 45
#  Done MP KaiserXImpact#God
# 46
#  Done lookin for mommy#eboy
# 47
#  Done auto dnd#auto
# 48
#  Done FyaH#ESP
# 49
#  Done Ryuga#8055
# 50
#  Done Gotakson#0001
# 51
#  Done eng Na Choice đá#MinHy
# 52
#  Done kody#0444
# 53
#  Done arri#7777
# 54
#  Done Spice#Mommy
# 55
#  Done Palmolives#6640
# 56
#  Done kimanier#EUW
# 57
#  Done hackerend#booby
# 58
#  Done KC7#BP88
# 59
#  Done wise#1000
# 60
#  Done Luminite#Come
# 61
#  Done Sir McGirth#big
# 62
#  Done MyLove#you
# 63
#  Done mantoneee#xhek
# 64
#  Done Skull Shocker#Solo
# 65
#  Done Scaleny#Dakk
# 66
# Failed Sora#SO02
#  Done B0Y#00002
# 68
#  Done Lepatats#EUW
# 69
#  Done kuvi#rina
# 70
#  Done brat#CSGO
# 71
#  Done Medou#FUNDR
# 72
#  Done Kajitsulol#Rusty
# 73
#  Done B3ASTM0D3#LANA
# 74
#  Done flyingmyvi#MYVI
# 75
#  Done romelpezzzz#nashe
# 76
#  Done XarDrax#drax
# 77
#  Done Masala Chicken#1212
# 78
#  Done clarify#2369
# 79
#  Done Aurxllie#bunny
# 80
#  Done Dysania#AWAKE
# 81
#  Done MrCrked#7322
# 82
#  Done PITFALLTV#N01
# 83
#  Done Rambo#8704
# 84
#  Done ArtudNay#Kat
# 85
# Failed daylight pill#4081
#  Done vitalis961#2031
# 87
#  Done Nvoyn3r#6456
# 88
#  Done ладно#9529
# 89
#  Done SkillfulBubbleT#5294
# 90
#  Done Valentine#vel
# 91
#  Done GBoyHi#NOOB
# 92
#  Done agooo#007
# 93
#  Done Individuo30#6524
# 94
#  Done дед быдла#daddy
# 95
#  Done SwagAngel#whiff
# 96
#  Done Smeedrejat#best
# 97
#  Done Radikaler Ronny#afd
# 98
#  Done RyaanxX#9910
# 99
#  Done september 24#1805
# 100
#  Done Obstsalat#Miau
# 101
#  Done Blackyy#Trxsh
# 102
#  Done kukasbacsi#tej
# 103
#  Done Fladalu#EUW
# 104
#  Done SKIL#3115
# 105
#  Done BAKI HANMA#6128
# 106
#  Done clav111#111
# 107
#  Done DucksGoQuack#nolol
# 108
#  Done ZachMadeekBeach#6969
# 109
#  Done eastdakota208#9002
# 110
#  Done Iceッ#0406
# 111
#  Done N0t4lxx#2140
# 112
#  Done d0nt#1taps
# 113
#  Done Bloomhed#9623
# 114
#  Done Kashya#Sage
# 115
#  Done GeTreXx#Bucky
# 116
#  Done cobra#0666
# 117
# Failed Elαッ#Krmit
#  Done British Man#Brit
# 119
#  Done FriendlyNSG#4488
# 120
#  Done PH0EN1X#CoW
# 121
#  Done Asher#ohayo
# 122
#  Done need feet pics#666
# 123
#  Done emevaelx#1337
# 124
#  Done Za Russian секс7#maks7
# 125
#  Done 이 년들을 믿지마#0307
# 126
#  Done SHADOW#OOOO
# 127
#  Done Rodys Tricks#777
# 128
#  Done JETAway#way
# 129
#  Done IRZ dragnwsniper#irzfy
# 130
#  Done bunnyheadbaby#9251
# 131
#  Done Ricmaranga#GGs
# 132
#  Done ChaosXIII#XIII
# 133
#  Done TRIS TAINT#imbad
# 134
#  Done cinnabunny#boo
# 135
#  Done dynamickitty23#0001
# 136
#  Done andjelaツ#2424
# 137
#  Done riceuwu#666
# 138
#  Done FTSW Tubbirdd#Zaddy
# 139
#  Done Rule34#3207
# 140
#  Done kia kaha#7405
# 141
#  Done TGS itzy#TTV
# 142
#  Done RikaChuz#EUW
# 143
# Failed RikaChu#7224
#  Done zertuny#1220
# 145
#  Done her moon#lxrd
# 146
#  Done AMBASSADOR#NOTAG
# 147
#  Done goofy ahh xotic#0000
# 148
#  Done LAUHAX#1337
# 149
#  Done Tokyoo#Jihyo
# 150
#  Done iVyLux#002
# 151
#  Done interlude#aceml
# 152
#  Done G2K Ch1kita#Suz
# 153
#  Done seireИ 吉神#ynwa
# 154
#  Done BigTiddieGoth#alone
# 155
#  Done f0urK#death
# 156
#  Done 黒Jet#dead
# 157
#  Done Maey#nani
# 158
#  Done G2K Tessa#1668
# 159
#  Done xShootzxx#GOAT
# 160
#  Done Epablo#1212
# 161
#  Done NowHiringKittens#BIG D
# 162
#  Done Xess#Clean
# 163
#  Done Oli#4500
# 164
#  Done Chear#3383
# 165
#  Done Fantazer#8131
# 166
#  Done Axela0ss#01113
# 167
#  Done Kyedoo#shoko
# 168
#  Done Byakya#AIM
# 169
#  Done GMB DoJ#69420
# 170
#  Done よわよわのゆう#WCT
# 171
#  Done TL F4rceFlash#TTV
# 172
#  Done atomcorp#COZA
# 173
#  Done Alxc#Vibes
# 174
#  Done Tripppy#OCE
# 175
#  Done kelow#domi
# 176
#  Done Fornika2r#dontu
# 177
#  Done zadiakdeuS#nashe
# 178
#  Done Master Oogway#1155
# 179
#  Done peachy#0806
# 180
#  Done valazio195#BUMI
# 181
#  Done MezX#06060
# 182
#  Done degoreo#nyaw
# 183
#  Done YAHANU#1308
# 184
#  Done monkedesgraciao#monke
# 185
#  Done ItsLiu#0001
# 186
#  Done OnYourLeft#十十十
# 187
#  Done STRANGe#Tenz
# 188
#  Done rasbarruy#1tap
# 189
#  Done wennsdae#phjei
# 190
#  Done RainyDevil#TTC
# 191
#  Done PachecoTvOficial#2578
# 192
#  Done Yakult#hello
# 193
#  Done drexton#1301
# 194
#  Done feraxhp#Yuly
# 195
#  Done pollo#1205
# 196
#  Done Soupy#1228
# 197
#  Done vye#1only
# 198
#  Done rei#silly
# 199
#  Done forsik#bad
# 200
#  Done ValorJett#6108
# 201
#  Done ttvrevolversmoke#4592
# 202
#  Done Kung Fu Kenny#6449
# 203
#  Done bell#ash
# 204
#  Done Eulogy#IRIS
# 205
#  Done snorlaxxatives#1309
# 206
#  Done dread#1437
# 207
#  Done Exo#IMMO
# 208
#  Done Joyst1ck#1337
# 209
#  Done ADIRE Tressort#BELG
# 210
#  Done Frozen#vlrnt
# 211
# Failed ladies sommelie#carry
#  Done Skrub#4925
# 213
#  Done 锅包肉#W01
# 214
#  Done Raékwon#1400
# 215
#  Done NightmareFuel#koka
# 216
#  Done Hodg#1415
# 217
#  Done Shold#4298
# 218
#  Done SLZ TOXiN#69XXX
# 219
#  Done ReverseWK#7299
# 220
#  Done quet#1312
# 221
#  Done Señοrita#Toxic
# 222
#  Done PizzA stEvE#sexy
# 223
#  Done yuk1koちゃん#ITZY
# 224
#  Done FLseleur#4444
# 225

# %%
print(len(id))
print(len(rank))
print(len(mode))
print(len(win_per))
print(len(kd))
print(len(dmg_per_rnd))
print(len(region))
print(len(acc_head_per),len(acc_head_hits),len(acc_body_per),len(acc_body_hits),len(acc_leg_per),len(acc_leg_hits))
print(len(matchs),len(headshot_per),len(wins),len(kills),len(kill_per_rnd))
print(len(top_agent_name),len(top_agent_time),len(top_agent_matchs),len(top_agent_win_per),len(top_agent_kd),len(top_agent_adr))
# Out:
# 225
# 225
# 225
# 225
# 225
# 225
# 225
# 225 225 225 225 225 225
# 225 225 225 225 225
# 225 225 225 225 225 225

# %%
# print([i[0] for i in headshot_per])

# %%
now = datetime.now()
dt_string = now.strftime("%d_%m_%Y")

df = pd.DataFrame({'id':id,'rank':rank,'win%':win_per,'k/d':kd,'dmg/rnd':dmg_per_rnd, 'region':region, 
'acc_head_per':acc_head_per, 'acc_head_hits':acc_head_hits,'acc_body_per':acc_body_per,'acc_body_hits':acc_body_hits,'acc_leg_per':acc_leg_per,'acc_leg_hits':acc_leg_hits,
'matchs':matchs,'headshot_per':headshot_per,'wins':wins,'kills':kills,'kill_per_rnd':kill_per_rnd,
'top_agent_name':top_agent_name,'top_agent_time':top_agent_time,'top_agent_matchs':top_agent_matchs,'top_agent_win_per':top_agent_win_per,'top_agent_kd':top_agent_kd,'top_agent_adr':top_agent_adr})

df.to_csv('data/valo_data_master '+dt_string+'.csv',mode = 'a',header=False,index=False)
